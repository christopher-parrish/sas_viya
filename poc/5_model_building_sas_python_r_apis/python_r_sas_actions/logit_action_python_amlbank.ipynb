# %%
##################################################
###     Train & Register SAS Logit Model       ###
##################################################

###################
### Credentials ###
###################

import os
import sys
from pathlib import Path

filepath = input("file path to credentials: ")
sys.path.append(filepath)
from credentials import hostname, session, port, protocol, wd, output_dir, git_dir, token_dir, token, token_refresh, token_pem, username

# %%
#############################
### Connect with SAS Viya ###
#############################

import swat

access_token = open(token, "r").read()
conn =  swat.CAS(hostname=hostname, username=None, password=access_token, ssl_ca_list=token_pem, protocol=protocol)
print(conn.serverstatus())
# Out:
# NOTE: Grid node action status report: 1 nodes, 9 total actions executed.
# [About]
#
#  {'CAS': 'Cloud Analytic Services',
#   'CASCacheLocation': 'CAS Disk Cache',
#   'CASHostAccountRequired': 'OPTIONAL',
#   'Copyright': 'Copyright © 2014-2025 SAS Institute Inc. All Rights Reserved.',
#   'GlobalReadOnlyMode': 'NO',
#   'ServerTime': '2025-07-17T18:47:20Z',
#   'System': {'Hostname': 'controller.sas-cas-server-default.innovationlab.svc.cluster.local',
#    'Linux Distribution': 'Red Hat Enterprise Linux release 8.10 (Ootpa)',
#    'Model Number': 'x86_64',
#    'OS Family': 'LIN X64',
#    'OS Name': 'Linux',
#    'OS Release': '5.15.0-1090-azure',
#    'OS Version': '#99-Ubuntu SMP Thu May 22 21:15:50 UTC 2025'},
#   'Transferred': 'NO',
#   'Version': '4.00',
#   'VersionLong': 'V.04.00M0P06092025',
#   'Viya Release': '20250702.1751427964045',
#   'Viya Version': 'Stable 2025.06',
#   'license': {'expires': '08Jul2027:00:00:00',
#    'gracePeriod': 0,
#    'site': 'CIS CREATE INNOVATION LAB (ENTERPRISE-RISK-MRM-SPI',
#    'siteNum': 70180938,
#    'warningPeriod': 15}}
#
# [nodestatus]
#
#  Node Status
#
#                                                  name        role  uptime  running  stalled
#  0  controller.sas-cas-server-default.innovationla...  controller   2.431        0        0
#
# [server]
#
#  Server Status
#
#     nodes  actions
#  0      1        9
#
# + Elapsed: 0.000577s, user: 0.00039s, sys: 0.000134s, mem: 0.304mb

# %%
#############################
### Identify Table in CAS ###
#############################

### caslib and table to use in modeling
caslib = 'public'
in_mem_tbl = 'AML_BANK_PREP'

### load table in-memory if not already exists in-memory ###
if conn.table.tableExists(caslib=caslib, name=in_mem_tbl).exists<=0:
    conn.table.loadTable(caslib=caslib, path=str(in_mem_tbl+str('.sashdat')), 
                         casout={'name':in_mem_tbl, 'caslib':caslib, 'promote':True})
    
### show table to verify
conn.table.tableInfo(caslib=caslib, wildIgnore=False, name=in_mem_tbl)
# Out:
# [TableInfo]
#
#              Name   Rows  Columns  IndexedColumns Encoding        CreateTimeFormatted           ModTimeFormatted        AccessTimeFormatted JavaCharSet    CreateTime       ModTime    AccessTime  Global  Repeated  View  MultiPart             SourceName SourceCaslib  Compressed                Creator Modifier     SourceModTimeFormatted  SourceModTime TableRedistUpPolicy
#  0  AML_BANK_PREP  14302       27               0    utf-8  2025-07-15T16:31:21+00:00  2025-07-15T16:31:21+00:00  2025-07-17T07:48:19+00:00        UTF8  2.068216e+09  2.068216e+09  2.068358e+09       1         0     0          0  AML_BANK_PREP.sashdat       Public           0  Chris.Parrish@sas.com           2025-03-31T16:07:29+00:00   2.059056e+09       Not Specified
#
# + Elapsed: 0.0067s, user: 0.000178s, sys: 0.00323s, mem: 0.896mb

# %%
########################
### Create Dataframe ###
########################

dm_inputdf =  conn.CASTable(in_mem_tbl, caslib=caslib)

### print columns for review of model parameters
conn.table.columnInfo(table={"caslib":caslib, "name":in_mem_tbl})
# Out:
# [ColumnInfo]
#
#                           Column                                              Label  ID    Type  RawLength  FormattedLength Format  NFL  NFD
#  0                    account_id                                  unique identifier   1  double          8               12           0    0
#  1              num_transactions  number of transactions financial services cust...   2  double          8               12           0    0
#  2                  credit_score                              customer credit score   3  double          8               12           0    0
#  3         marital_status_single                                                      4  double          8               12           0    0
#  4        marital_status_married                                                      5  double          8               12           0    0
#  5       marital_status_divorced                                                      6  double          8               12           0    0
#  6            analytic_partition                                                      7  double          8               12           0    0
#  7                  ml_indicator  indicator for money laundering event no (0), y...   8  double          8               12           0    0
#  8       checking_only_indicator  indicator for whether customer only has a chec...   9  double          8               12           0    0
#  9           prior_ctr_indicator  indicator for whether the customer has a curre...  10  double          8               12           0    0
#  10  address_change_2x_indicator  indicator for whether customer changed address...  11  double          8               12           0    0
#  11   cross_border_trx_indicator  indicator for whether customer had a cross bor...  12  double          8               12           0    0
#  12  in_person_contact_indicator  indicator for whether customer has had in-pers...  13  double          8               12           0    0
#  13           linkedin_indicator  indicator for whether customer has a current L...  14  double          8               12           0    0
#  14        atm_deposit_indicator  indicator for whether customer has used an ATM...  15  double          8               12           0    0
#  15         trx_10ksum_indicator  indicator for whether a rolling 1 month sum of...  16  double          8               12           0    0
#  16    common_merchant_indicator  indicator for whether customer transfers <10k ...  17  double          8               12           0    0
#  17     direct_deposit_indicator  indicator for whether customer has recurring d...  18  double          8               12           0    0
#  18     citizenship_country_risk  ordinal risk ranking of customer country of ci...  19  double          8               12           0    0
#  19              occupation_risk  ordinal risk ranking of customer occupation (0...  20  double          8               12           0    0
#  20      num_acctbal_chgs_gt2000  number of times customer account balance chang...  21  double          8               12           0    0
#  21         distance_to_employer  distance between customer's residence and empl...  22  double          8               12           0    0
#  22             distance_to_bank  distance between customer's residence and near...  23  double          8               12           0    0
#  23                       income                                    customer income  24  double          8               12           0    0
#  24        primary_transfer_cash  primary transfer type across all transfers ove...  25  double          8               12           0    0
#  25       primary_transfer_check  primary transfer type across all transfers ove...  26  double          8               12           0    0
#  26        primary_transfer_wire  primary transfer type across all transfers ove...  27  double          8               12           0    0
#
# + Elapsed: 0.0011s, user: 0.000675s, sys: 0.000242s, mem: 1.21mb

# %%
########################
### Model Parameters ###
########################

# import python libraries
import numpy as np
import pandas as pd
from pathlib import Path
from sklearn.utils import shuffle
### import actionsets
conn.loadactionset('regression')
conn.loadactionset('astore')

### model arugments
event = 'LAST'
selection_method = 'STEPWISE'

### model manager information
metadata_output_dir = 'outputs'
model_name = 'logit_SAS'
project_name = 'Risk Score'
description = 'Logit SAS'
model_type = 'Logistic Regression'
metadata_output_dir = 'outputs'

### define macro variables for model
dm_dec_target = 'ml_indicator'
dm_partitionvar = 'analytic_partition'
create_new_partition = 'no' # 'yes', 'no'
dm_key = 'account_id' 
dm_classtarget_level = ['0', '1']
dm_partition_validate_val, dm_partition_train_val, dm_partition_test_val = [0, 1, 2]
dm_partition_validate_perc, dm_partition_train_perc, dm_partition_test_perc = [0.3, 0.6, 0.1]

### create list of rejected predictor columns
rejected_predictors = [
    'atm_deposit_indicator', 
    'citizenship_country_risk', 
    'distance_to_bank',
    'distance_to_employer', 
    'income', 
    'num_acctbal_chgs_gt2000',
    'occupation_risk'
    ]

### create partition column, if not already in dataset
if create_new_partition == 'yes':
    dm_inputdf = shuffle(dm_inputdf)
    dm_inputdf.reset_index(inplace=True, drop=True)
    validate_rows = round(len(dm_inputdf)*dm_partition_validate_perc)
    train_rows = round(len(dm_inputdf)*dm_partition_train_perc) + validate_rows
    test_rows = len(dm_inputdf)-train_rows
    dm_inputdf.loc[0:validate_rows,dm_partitionvar] = dm_partition_validate_val
    dm_inputdf.loc[validate_rows:train_rows,dm_partitionvar] = dm_partition_train_val
    dm_inputdf.loc[train_rows:,dm_partitionvar] = dm_partition_test_val

### var to consider in bias assessment
bias_var = 'cross_border_trx_indicator'
# Out:
# NOTE: Added action set 'regression'.
# NOTE: Added action set 'astore'.

# %%
##############################
### Final Modeling Columns ###
##############################

### create list of model variables
dm_input = list(dm_inputdf.columns.values)
macro_vars = (dm_dec_target + ' ' + dm_partitionvar + ' ' + dm_key).split()
rejected_vars = rejected_predictors + macro_vars
for i in rejected_vars:
    dm_input.remove(i)

### create prediction variables
dm_predictionvar = [str('P_') + dm_dec_target + dm_classtarget_level[0], str('P_') + dm_dec_target + dm_classtarget_level[1]]
dm_classtarget_intovar = str('I_') + dm_dec_target

# %%
#####################
### Training Code ###
#####################

### create names of tables for action set
astore_tbl = str(in_mem_tbl+str('_astore'))
cas_score_tbl = str(in_mem_tbl+str('_score'))
cas_out_tbl = str(in_mem_tbl+str('_model'))

### estimate & fit model
dm_model = conn.regression.logistic(
    model={"depVars":[{"name":dm_dec_target, "options":{"event":event}}], "effects":[{"vars":dm_input}],"informative":True },
    partByVar={"name":dm_partitionvar, "train":str(dm_partition_train_val), "valid":str(dm_partition_validate_val),"test":str(dm_partition_test_val)},
    output={"casOut": {"name":cas_out_tbl, "caslib":caslib, "replace":True}, "copyVars":{dm_dec_target}, "into":dm_classtarget_intovar},
    selection={"method":selection_method},
    table={"name":in_mem_tbl, "caslib":caslib},
    store={"name":astore_tbl, "caslib":caslib, "replace":True})

### score full data
conn.astore.score(
    table={"name":in_mem_tbl, "caslib":caslib}, 
    copyvars=[dm_dec_target, dm_partitionvar],
    casout={"name":cas_score_tbl, "replace":True},
    rstore={"name":astore_tbl, "caslib":caslib})
score_astore = conn.CASTable(cas_score_tbl)

### create tables with predicted values
dm_scoreddf = conn.CASTable(score_astore).to_frame()
dm_scoreddf[dm_dec_target] = dm_scoreddf[dm_dec_target].astype(int)
trainData = dm_scoreddf[dm_scoreddf[dm_partitionvar]==dm_partition_train_val][[dm_dec_target, dm_predictionvar[1]]].rename(columns=lambda x:'0')
testData = dm_scoreddf[dm_scoreddf[dm_partitionvar]==dm_partition_test_val][[dm_dec_target, dm_predictionvar[1]]].rename(columns=lambda x:'0')
validData = dm_scoreddf[dm_scoreddf[dm_partitionvar]==dm_partition_validate_val][[dm_dec_target, dm_predictionvar[1]]].rename(columns=lambda x:'0')
trainData = pd.DataFrame(trainData)
testData = pd.DataFrame(testData)
validData = pd.DataFrame(validData)

### print model & results
print(dm_model)
conn.table.tableInfo(caslib=caslib, wildIgnore=False, name=astore_tbl)
print(conn.astore.describe(rstore={"name":astore_tbl, "caslib":caslib}, epcode=True).Description)
print(conn.astore.describe(rstore={"name":astore_tbl, "caslib":caslib}, epcode=True).InputVariables)
print(conn.astore.describe(rstore={"name":astore_tbl, "caslib":caslib}, epcode=True).OutputVariables)
print(conn.astore.describe(rstore={"name":astore_tbl, "caslib":caslib}, epcode=True).epcode)
model_astore = conn.CASTable(astore_tbl, caslib=caslib)
# Out:
# NOTE: Convergence criterion (ABSGCONV=1E-7) satisfied.
# NOTE: 751715 bytes were written to the table "AML_BANK_PREP_astore" in the caslib "public".
# [ModelInfo]
#
#  Model Information
#
#           RowId             Description                        Value
#  0         DATA             Data Source                AML_BANK_PREP
#  1  RESPONSEVAR       Response Variable                 ml_indicator
#  2         DIST            Distribution                       Binary
#  3         LINK           Link Function                        Logit
#  4         TECH  Optimization Technique  Newton-Raphson with Ridging
#
# [NObs]
#
#  Number of Observations
#
#     RowId                  Description    Value  Training  Validation  Testing
#  0  NREAD  Number of Observations Read  14302.0    8581.0      4291.0   1430.0
#  1  NUSED  Number of Observations Used  14302.0    8581.0      4291.0   1430.0
#
# [OutputCasTables]
#
#     casLib                  Name Label   Rows  Columns                                           casTable
#  0  Public  AML_BANK_PREP_astore            1        2  CASTable('AML_BANK_PREP_astore', caslib='Public')
#  1  Public   AML_BANK_PREP_model        14302        3   CASTable('AML_BANK_PREP_model', caslib='Public')
#
# [ResponseProfile]
#
#  Response Profile
#
#     OrderedValue Outcome  ml_indicator     Freq  Training  Validation  Testing Modeled
#  0             1       0           0.0  13586.0    8155.0      4065.0   1366.0
#  1             2       1           1.0    716.0     426.0       226.0     64.0       *
#
# [SelectedModel.Dimensions]
#
#  Dimensions
#
#           RowId                 Description  Value
#  0  NDESIGNCOLS           Columns in Design     13
#  1     NEFFECTS           Number of Effects     13
#  2    MAXEFCOLS          Max Effect Columns      1
#  3   DESIGNRANK              Rank of Design     13
#  4      OPTPARM  Parameters in Optimization     13
#
# [SelectedModel.FitStatistics]
#
#  Fit Statistics
#
#         RowId                Description     Training   Validation     Testing
#  0       M2LL          -2 Log Likelihood   577.855537   324.507039  116.414460
#  1        AIC    AIC (smaller is better)   603.855537   350.507039  142.414460
#  2       AICC   AICC (smaller is better)   603.898025   350.592146  142.671522
#  3        SBC    SBC (smaller is better)   695.600511   433.242615  210.865046
#  4        ASE       Average Square Error     0.009289     0.010446    0.010679
#  5   M2LLNULL  -2 Log L (Intercept-only)  3388.934654  1770.452811  522.729920
#  6    RSQUARE                   R-Square     0.279344     0.286071    0.247336
#  7     ADJRSQ      Max-rescaled R-Square     0.856159     0.846186    0.807808
#  8   MCFADDEN        McFadden's R-Square     0.829488     0.816710    0.777295
#  9   MISCLASS     Misclassification Rate     0.012469     0.014216    0.013287
#  10  DIFFMEAN        Difference of Means     0.804526     0.809753    0.757290
#
# [SelectedModel.GlobalTest]
#
#  Testing Global Null Hypothesis: BETA=0
#
#                 Test  DF        ChiSq  ProbChiSq
#  0  Likelihood Ratio  12  2811.079118        0.0
#
# [SelectedModel.ParameterEstimates]
#
#  Parameter Estimates
#
#                           Effect  _miss_                    Parameter                     ParmName   DF  Estimate    StdErr       ChiSq     ProbChiSq
#  0                     Intercept     NaN                    Intercept                    Intercept  1.0 -6.572268  0.465923  198.976906  3.492180e-45
#  1                  credit_score     NaN                 credit_score                 credit_score  1.0 -1.171814  0.115393  103.124213  3.147802e-24
#  2         marital_status_single     NaN        marital_status_single        marital_status_single  1.0  2.490177  0.242011  105.874329  7.856280e-25
#  3       checking_only_indicator     NaN      checking_only_indicator      checking_only_indicator  1.0  0.920823  0.230782   15.920148  6.607163e-05
#  4           prior_ctr_indicator     NaN          prior_ctr_indicator          prior_ctr_indicator  1.0  0.986600  0.233613   17.835655  2.408280e-05
#  5   address_change_2x_indicator     NaN  address_change_2x_indicator  address_change_2x_indicator  1.0  1.310840  0.232755   31.717602  1.782989e-08
#  6    cross_border_trx_indicator     NaN   cross_border_trx_indicator   cross_border_trx_indicator  1.0  1.303712  0.250274   27.135150  1.897169e-07
#  7   in_person_contact_indicator     NaN  in_person_contact_indicator  in_person_contact_indicator  1.0 -1.685922  0.236184   50.953434  9.458339e-13
#  8            linkedin_indicator     NaN           linkedin_indicator           linkedin_indicator  1.0 -1.743899  0.264647   43.421832  4.412376e-11
#  9          trx_10ksum_indicator     NaN         trx_10ksum_indicator         trx_10ksum_indicator  1.0  3.129128  0.245220  162.830349  2.724482e-37
#  10    common_merchant_indicator     NaN    common_merchant_indicator    common_merchant_indicator  1.0  3.632771  0.258059  198.170750  5.236296e-45
#  11     direct_deposit_indicator     NaN     direct_deposit_indicator     direct_deposit_indicator  1.0 -1.376545  0.230837   35.560631  2.472341e-09
#  12       primary_transfer_check     NaN       primary_transfer_check       primary_transfer_check  1.0 -2.416312  0.244803   97.425330  5.592599e-23
#
# [SelectionInfo]
#
#  Selection Information
#
#             RowId                Description     Value  NValue
#  0         METHOD           Selection Method  Stepwise     NaN
#  1   SELCRITERION           Select Criterion       SBC     NaN
#  2  STOPCRITERION             Stop Criterion       SBC     NaN
#  3      HIERARCHY  Effect Hierarchy Enforced      None     NaN
#  4    STOPHORIZON               Stop Horizon         3     3.0
#
# [Summary.ConvergenceStatus]
#
#  Convergence Status
#
#                                               Reason  Status   MaxGradient  Separation
#  0  Convergence criterion (ABSGCONV=1E-7) satisfied.       0  5.493650e-08          -3
#
# [Summary.SelectedEffects]
#
#  Selected Effects
#
#                 Label                                            Effects
#  0  Selected Effects:  Intercept credit_score marital_status_single c...
#
# [Summary.SelectionReason]
#
#  Selection Reason
#
#                                Reason
#  0  The model at step 12 is selected.
#
# [Summary.SelectionSummary]
#
#  Selection Summary
#
#     Control  Step                EffectEntered EffectRemoved  nEffectsIn          SBC  OptSBC
#  0              0                    Intercept                         1  3397.991960       0
#  1        -     1         trx_10ksum_indicator                         2  1777.285331       0
#  2              2    common_merchant_indicator                         3  1606.987639       0
#  3              3       primary_transfer_check                         4  1372.103550       0
#  4              4                 credit_score                         5  1155.887126       0
#  5              5        marital_status_single                         6   942.458573       0
#  6              6  in_person_contact_indicator                         7   865.392061       0
#  7              7     direct_deposit_indicator                         8   810.748786       0
#  8              8           linkedin_indicator                         9   767.462115       0
#  9              9  address_change_2x_indicator                        10   733.460172       0
#  10            10   cross_border_trx_indicator                        11   712.497674       0
#  11            11          prior_ctr_indicator                        12   702.460164       0
#  12            12      checking_only_indicator                        13   695.153222       1
#
# [Summary.StopReason]
#
#  Stop Reason
#
#                                                Reason  Code
#  0  Stepwise selection stopped because adding or r...     8
#
# [Timing]
#
#  Task Timing
#
#              RowId                  Task      Time   RelTime
#  0           SETUP     Setup and Parsing  0.004665  0.014462
#  1    LEVELIZATION          Levelization  0.003837  0.011896
#  2  INITIALIZATION  Model Initialization  0.001188  0.003683
#  3            SSCP      SSCP Computation  0.007996  0.024790
#  4         FITTING       Model Selection  0.292382  0.906465
#  5          OUTPUT  Creating Output Data  0.002288  0.007094
#  6           STORE         Model Storing  0.009372  0.029056
#  7         DISPLAY               Display  0.000489  0.001516
#  8         CLEANUP               Cleanup  0.000468  0.001451
#  9           TOTAL                 Total  0.322552  1.000000
#
# + Elapsed: 0.334s, user: 1.51s, sys: 0.285s, mem: 3.14mb
# Basic Information
#
#          Attribute               Value
# 0  Analytic Engine            logistic
# 1     Time Created  17Jul2025:18:48:06
# Input Variables
#
#                            Name  Length   Role      Type RawType FormatName
# 0   address_change_2x_indicator     8.0  Input  Interval     Num
# 1       checking_only_indicator     8.0  Input  Interval     Num
# 2     common_merchant_indicator     8.0  Input  Interval     Num
# 3                  credit_score     8.0  Input  Interval     Num
# 4    cross_border_trx_indicator     8.0  Input  Interval     Num
# 5      direct_deposit_indicator     8.0  Input  Interval     Num
# 6   in_person_contact_indicator     8.0  Input  Interval     Num
# 7            linkedin_indicator     8.0  Input  Interval     Num
# 8         marital_status_single     8.0  Input  Interval     Num
# 9        primary_transfer_check     8.0  Input  Interval     Num
# 10          prior_ctr_indicator     8.0  Input  Interval     Num
# 11         trx_10ksum_indicator     8.0  Input  Interval     Num
# Output Variables
#
#               Name  Length Type                      Label
# 0  P_ml_indicator1     8.0  Num  Predicted: ml_indicator=1
# 1  P_ml_indicator0     8.0  Num  Predicted: ml_indicator=0
# 2   I_ml_indicator     8.0  Num         Into: ml_indicator
# data sasep.out;
#   dcl package score sc();
#   dcl double "address_change_2x_indicator" having label n'indicator for whether customer changed addresses twice within the past year';
#   dcl double "checking_only_indicator" having label n'indicator for whether customer only has a checking account with bank';
#   dcl double "common_merchant_indicator" having label n'indicator for whether customer transfers <10k along with other customers <10k to common merchant';
#   dcl double "credit_score" having label n'customer credit score';
#   dcl double "cross_border_trx_indicator" having label n'indicator for whether customer had a cross border transfer over the past year';
#   dcl double "direct_deposit_indicator" having label n'indicator for whether customer has recurring direct depost to account';
#   dcl double "in_person_contact_indicator" having label n'indicator for whether customer has had in-person bank visit';
#   dcl double "linkedin_indicator" having label n'indicator for whether customer has a current LinkedIn account';
#   dcl double "marital_status_single";
#   dcl double "primary_transfer_check" having label n'primary transfer type across all transfers over the past year - check';
#   dcl double "prior_ctr_indicator" having label n'indicator for whether the customer has a currency transaction report in the past year';
#   dcl double "trx_10ksum_indicator" having label n'indicator for whether a rolling 1 month sum of transfers exceeded 10k over past year';
#   dcl double "P_ml_indicator1" having label n'Predicted: ml_indicator=1';
#   dcl double "P_ml_indicator0" having label n'Predicted: ml_indicator=0';
#   dcl double "I_ml_indicator" having label n'Into: ml_indicator';
#   keep "P_ml_indicator1" "P_ml_indicator0" "I_ml_indicator";
#   varlist allvars[_all_];
#   method init();
#     sc.setvars(allvars);
#     sc.setKey(n'615E01D27AA1DF1ECFC42A8E6DC32B9069245153');
#   end;
#   method preScoreRecord();
#   end;
#   method postScoreRecord();
#   end;
#   method term();
#   end;
#   method run();
#     set sasep.in;
#     preScoreRecord();
#     sc.scoreRecord();
#     postScoreRecord();
#   end;
# enddata;

# %%
#######################################
### Register Model in Model Manager ###
## Ensure Model Does Not Exist in MM ##
##### Using PZMM Zips Up Metadata #####
#######################################

import shutil
from sasctl import pzmm as pzmm
from sasctl import Session
from sasctl import register_model, publish_model
from sasctl._services.model_repository import ModelRepository as mr

### create session in cas
sess=Session(hostname, username=username, password=password, verify_ssl=False, protocol="http")

### create directories for metadata
output_path = Path(output_dir) / metadata_output_dir / model_name
if output_path.exists() and output_path.is_dir():
    shutil.rmtree(output_path)
os.makedirs(output_path)

### create metadata and import to model manager
pzmm.JSONFiles().calculateFitStat(trainData=trainData, testData=testData, validateData=validData, jPath=output_path)
pzmm.JSONFiles().generateROCLiftStat(dm_dec_target, int(dm_classtarget_level[1]), conn, trainData=trainData, testData=testData, validateData=validData, jPath=output_path)
file_list = os.listdir(output_path)
files = []
for i in file_list:
    new_dict = {'name':i, 'file':open(output_path / i)}
    files.append(new_dict)
with sess:
    reg_model = register_model(model_astore, model_name, project_name, files=files, force=True, version='latest')
#   pub_model = publish_model(model_name, 'maslocal')
#   score_example = pub_model.score(input1=1, input2=2, etc.)
